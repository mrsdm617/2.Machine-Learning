# %%
import pickle

# %%
# To load a saved machine learning model using Python’s pickle module

loaded_model=pickle.load(open("finalized_model_linear.sav",'rb'))  # Assigns the loaded model to this variable & Opens the file in binary read mode('rb')
result=loaded_model.predict([[0]])     # Eventhough the salary for 0 experience is not given, intercet or bais is considered as a 0 experience value
# Out:
# C:\ProgramData\anaconda3\Lib\site-packages\sklearn\utils\validation.py:2749: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
result
# Out:
# array([[26777.3913412]])
